# %%
# !pip install pyarrow
# !pip install fastparquet

# %%
import pandas as pd
import os
import pickle as pkl
from functools import partial
from tqdm import tqdm

# %%
tweets_path = "/mlodata1/prakhar/all_available_tweets"
tweets_piped_path = "/mlodata1/prakhar/all_available_tweets_piped"
topics_path = "/mlodata1/prakhar/twitter_covid_insights/insights_All/topics.pkl"
topics = pkl.load(open(topics_path, 'rb'))[0]

# Nb. of tweets per day for normalization
day_flux_path = '/mlodata1/prakhar/twitter_covid_insights/insights_All/day_flux.pkl'
day_flux = pkl.load(open(day_flux_path, 'rb'))

# Read counts
trends_path = '/mlodata1/prakhar/twitter_covid_insights/insights_All/trends.pkl'
trends = pkl.load(open(trends_path, 'rb'))[0]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-88d82f4acaf4> in <module>
#      10 # Read counts
#      11 trends_path = '/mlodata1/prakhar/twitter_covid_insights/insights_All/trends.pkl'
# ---> 12 trends = pkl.load(open(trends_path, 'rb'))[0]
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mlodata1/prakhar/twitter_covid_insights/insights_All/trends.pkl'

# %%
for i, file in tqdm(enumerate(os.listdir(tweets_path))):
    if i == 1:
        break
    print(os.path.join(tweets_path, file))
    tweets = pd.read_parquet(os.path.join(tweets_path, file))
    print(os.path.join(tweets_piped_path, file))
    tweets_piped = pd.read_parquet(os.path.join(tweets_piped_path, file))

    #dated_tweets = pd.merge(piped_tweets, tweets[['id', 'created_at']], on='id', how='inner')
    #relevant_hashtags = topics[relevant_topic]
    #relevant_tweets = dated_tweets[dated_tweets.apply(lambda x: has_relevant_hashtag(x, relevant_hashtags), axis=1)]
    #topic_dfs[relevant_topic].append(relevant_tweets.copy())
tweets_piped
# Out:
# 0it [00:00, ?it/s]
# /mlodata1/prakhar/all_available_tweets/parsed_2020-12-02.parquet
# /mlodata1/prakhar/all_available_tweets_piped/parsed_2020-12-02.parquet
# 1it [00:06,  6.42s/it]
#         country_code lang   hashtags  \
# 0                 US   en
# 1               None   it
# 2                 MX   es
# 3               None   en
# 4                 DE   de
# ...              ...  ...        ...
# 2245692           IT   es
# 2245693           VN   en
# 2245694         None   en  #mabs,#ai
# 2245695         None   pt
# 2245696           PH   en
#
#                                               cleaned_text
# 0        user_placeholder Week... lost count... of lock...
# 1        CORONAVIRUS CALABRIA, CALANO I CONTAGI MA ANCO...
# 2        "con esto de la pandemia" la frase doble filo ...
# 3        user_placeholder make CBI ED inquiry of Mumbai...
# 4        Kein „Corona-Drama im Pflegeheim“ url_placeholder
# ...                                                    ...
# 2245692                                          qe horror
# 2245693  Possible HHS Pick Shielded Nursing Homes From ...
# 2245694  $ENZCLicensing Royalties $ENZC will receive fo...
# 2245695                    Esse cara tem bliss aí tá foda!
# 2245696  user_placeholder user_placeholder It’s also po...
#
# [2245697 rows x 4 columns]

# %%
tweets
# Out:
#                                                                   text lang  \
# id
# 1334177939018162179  @KristinBoymom Week... lost count... of lockdo...   en
# 1334177939311783936  CORONAVIRUS CALABRIA, CALANO I CONTAGI MA ANCO...   it
# 1334177941547171841  "con esto de la pandemia" la frase doble filo ...   es
# 1334177942444797953  @KishoriPednekar make CBI ED inquiry of Mumbai...   en
# 1334177944097452039  Kein „Corona-Drama im Pflegeheim“ https://t.co...   de
# ...                                                                ...  ...
# 1334282590208090112  Possible HHS Pick Shielded Nursing Homes From ...   en
# 1334282589075542016  $ENZC\n\nLicensing Royalties $ENZC will receiv...   en
# 1334282590455476225                    Esse cara tem bliss aí tá foda!   pt
# 1334282590623322114  Merry Main Street Face Mask https://t.co/3f99l...   en
# 1334282592707772418  @conorsen @barnejek It’s also possible in earl...   en
#
#                     country_code
# id
# 1334177939018162179           US
# 1334177939311783936         None
# 1334177941547171841           MX
# 1334177942444797953         None
# 1334177944097452039           DE
# ...                          ...
# 1334282590208090112           VN
# 1334282589075542016         None
# 1334282590455476225         None
# 1334282590623322114           US
# 1334282592707772418           PH
#
# [2541574 rows x 3 columns]
