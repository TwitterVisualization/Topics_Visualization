# %%
import numpy as np
import pandas as pd
import pickle as pkl
import sys
sys.path.insert(1,'../scripts')
from hash_utils import *
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/hartley/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/hartley/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
tweets_path  ="/mlo-container-scratch/hartley/tweets"
tweets_piped_path  ="/mlo-container-scratch/hartley/tweets_piped"
files = [os.path.join(tweets_path,f) for f in  sorted(os.listdir(tweets_path))]
piped_files = [os.path.join(tweets_piped_path,f) for f in  sorted(os.listdir(tweets_piped_path))]

# %%
piped_files[100]
# Out:
# '/mlo-container-scratch/hartley/tweets_piped/parsed_2020-01-09.parquet'

# %%
with open('/mlo-container-scratch/hartley/twitter_covid_insights/insights_All/texts.txt', encoding='utf8') as f:
    lines = f.readlines()

# %%
lines
# Out:
# ['novel looks to be the culprit in the china pneumonia cluster . url_placeholder #coronavirus\n',
#  "hello family . i 'm selling all my lp collection due serious family problems . i 'm unemployed since the end of 2017 , last year lost my mom and i 'm desparate to get incomes for living . selling list : url_placeholder i appreciate rts to spread the word . url_placeholder #linkinpark\n",
#  'lumivia™ cpl provides serious seed protection against wireworm , cutworm , armyworm and pea leaf weevil . with a unique mode of action and a favourable environmental profile , it is proven to maximize stand and yield potential . learn more . \n',
#  "oh , and i 'm flying economy , which is a thing apparently . heaven knows what that 'll be like , but i thought it sounded quite cute . \n",
#  'user_placeholder ~ potentiality projections ~ what if 1975 china looked like 1930 us , 2000 china looked like 1942 us , & 2006 china looked like 1945 us ? what if china had an hst on 7/7/7 who saw us as a them ? in 1975 in china , george { came to a fork in the road & took it . is that time travel ? url_placeholder #43\n',
#  'this might be a problem ... “ chinese government has not yet publicly stated that a coronavirus is cause of the illness , which has infected at least 59 people . but the wall street journal reported that was the case earlier wednesday , citing unnamed sources ” url_placeholder \n',
#  'davante adams with those words of advice . enjoy : url_placeholder #packers\n',
#  'u.s war with china is inevitable . in the last two decades the rogue empire was busy killing , torturing & raping millions worldwide whilst china was busy building trade relationship . url_placeholder \n',
#  'giving cpr to dead pigeon url_placeholder \n',
#  'chinese health experts have determined that a “ new kind of coronavirus ” caused the mystery outbreak of viral pneumonia in wuhan which has hospitalised 59 people in the past week . url_placeholder #breaking\n',
#  "experts say the previously unidentified pneumonia in wuhan , central china 's hubei province , which has had 59 confirmed cases , is believed to be a new type of coronavirus . url_placeholder #breaking\n",
#  '$ xair 40 % upside in the past month but still very undervalued imho . new contracts and approvals will push this higher fast . \n',
#  'les experts affirment que la pneumonie non identifiée à wuhan , dans la province du hubei ( centre de la chine ) , qui a enregistré 59 cas confirmés , serait un nouveau type de coronavirus . url_placeholder #chine #china #virus\n',
#  '“ wash your hands & wash your butt. ” user_placeholder with the remedies . url_placeholder #gopackgo\n',
#  'user_placeholder user_placeholder a severe pandemic and the cascading impacts it would cause global . the why is the inequities associated with who will likely survive and thrive vs survive . the other why is limited options we have to prevent and respond . \n',
#  'preliminary research shows that the viral of unknown causes in wuhan , probably comes from a new strain of it ’ s different from the coronaviruses behind and and requires further scientific study . url_placeholder url_placeholder \n',
#  "wife : can you empty the dishwasher ? me ( editing a video of the iranian consultative assembly chanting `` death to america '' to make it look like they 're singing `` mr. brightside '' ) : kinda busy right now . url_placeholder #update #pneumonia #china #coronavirus #sars #mers\n",
#  'cctv : cause of wuhan pneumonia is a new type of coronavirus , according to preliminary tests by 9pm on january 7 by mainland experts . they have got the virus from a patient and detected the full genetic sequence . url_placeholder \n',
#  'cctv：武漢不明肺炎病源體為新型冠狀病毒 目前已知人類冠狀病毒有六種，其中四種致病性較低，另外兩種包括嚴重急性呼吸綜合症冠狀病毒，即「 」，及中東呼吸綜合症冠狀病毒，即「mers」，可引起嚴重呼吸系統疾病。 url_placeholder \n',
#  'keep your 🔋 powered ! our high-capacity power banks have the 💪 to keep you going on even the longest days 🕚 . url_placeholder #sars\n',
#  'for those friends who are experts on 80s sci-fi novels and movies , is there a way to roll back to 2019 ? 2020 is not going well , and we are just 8 days in , there is still time🙂 url_placeholder #ces2020\n',
#  "the virus circulating in china now has been described as a novel coronavirus , much like sars was . he says it 's not sars , but it 's from the same family . still a lot to learn about it . again , very high mutation rate ( base pairs x time ) and recombination . \n",
#  "today 's news , not found on cnn : ( 1 ) child porn on krugman 's computer . ( 2 ) hunter biden stole brother 's identity . ( 3 ) bill clinton with epstein & prince andrew 's young damsel . ( 4 ) iran 's `` retaliation '' did n't kill/injure americans , but downed an airliner full of mostly iranians . \n",
#  'china ’ s first bridge museum opened in wuhan ! the museum is located on the ground floor of the wuhan headquarters of china railway major bridge engineering group ( mbec ) . vr , 5d cinema and other cool technologies are used in the exhibition . url_placeholder \n',
#  '2020 resolution : convert more twitter friends to irl friends ! url_placeholder \n',
#  'i hate people that re-wipe the equipment you just used after you just wiped it down for the next person . screw you buddy . \n',
#  "it has determined that the originating in wuhan is caused by a new coronavirus . experts have obtained the virus ' whole genome sequences : china ' s national broadcaster url_placeholder \n",
#  "when is one of ya 'll gon na stop playing & be my pretend long distance girlfriend ? who do you have to send your cute selfies to ? nobody ? well i 'm right here ! i will gas you up boo ! and when you find something real i will gracefully exit our pretend relationship & wish you the best #pneumonia\n",
#  'jesus the us and iran are practically at war , australia ’ s a fireball , meghan markle yoko ono ’ d the royal family , justin bieber has lyme disease , and someone asked user_placeholder how to milk a whale . we ’ re only a week in and 2020 ’ s already outta pocket . \n',
#  '“ user_placeholder , a coronavirus expert at the university of north caroline . “ otherwise you ’ re just doing screening for fever — in the middle of respiratory disease season ? financial nightmare. ” taxpayers ’ feeling ... url_placeholder #btsiscoming #mots7\n',
#  'hear from two of my faves who help keep me together on a daily . exclusively on user_placeholder url_placeholder #hongkong\n',
#  'user_placeholder hi ! , the unroll you asked for : thread by user_placeholder north carolina incarceration rates stand out internationally most discriminatory lending… url_placeholder talk to you soon . 🤖 \n',
#  'i received a passing score from my first certification exam today . woah . \n',
#  'according to user_placeholder report , 1. a complete genome of a novel has been obtained . 2 . 15 positives have been detected based on such genome in molecular diagnostics . 3. viral isolation has been done on 1 sample which shows the morphology of coronavirus under em . \n',
#  "i like this headline because it 's one comma away from a command : virologists , weigh in on novel coronavirus in china 's outbreak ( also thankful for user_placeholder summary of wsj 's $ $ $ walled article ) url_placeholder #coronavirus\n",
#  'have a student struggling in grades 5th and up in math ? struggling in your college math course ? hire me for online or in person tutoring💁🏽♀️ url_placeholder \n',
#  "aftermath : many agencies were shared to have been `` at their calculators '' prior to the vote and plan on having their x1 members pursue solo careers like fan meetings , some agencies are looking into unit activities x1 disbandment was caused by the self interest of adults . \n",
#  'novel coronavirus causing pneumonia cluster in wuhan ? another news outlet says so , but no official announcement yet . url_placeholder \n',
#  'my roommate is a dumbass boomer and who looks dumb af when he got bronchitis \n',
#  'china-media rpt on mystery pneumonia in wuhan : a new type of coronavirus was detected in the lab , whole genome sequence of virus was obtained . 15 cases of + results of the new type of coronavirus were detected by nucleic acid detection method . url_placeholder h/t treyfish \n',
#  'latest news from state cctv ( china central television ) news about the identity of the wuhan pueminia cluster . a new form of is confirmed with sequencing and electron microscope . ( via bjnews/新京报 , 09/01/2020 ) . reference below . user_placeholder user_placeholder \n',
#  '$ 70 million donation from mining billionaire twiggy forrest $ 10m for volunteer army of 1,200 mining & agriculture workers to help rebuilding $ 10m to support devastated communities alongside user_placeholder & user_placeholder $ 50m for bushfire prevention planning 👏👏 user_placeholder #coronavirus\n',
#  'a wah gwaan yah so 😂😂😂😂 url_placeholder \n',
#  'this is the year i start tweeting about user_placeholder again . \n',
#  'pneumonia outbreak in china may be linked to new virus from sars , mers family : who url_placeholder url_placeholder \n',
#  "here 's a video to give you hope & make you smile : our warrior princess nusayba gave her liver donor user_placeholder a hug today after ringing the bell . after 9 months of enduring stage 4 liver cancer , she is officially cancer free . i 'm so proud of her . she is the bravest person i know . url_placeholder \n",
#  'radical leftists support all women except : conservative women pro life women christian women white women women who aren ’ t feminists women who don ’ t wear pussy hats women who refuse to kill unborn babies women who love their husband women who enjoy being a woman url_placeholder \n',
#  'update brote de neumonía viral en china : se trataría de un nuevo coronavirus ( pariente de sars y mers ) , se sospecha spillover de zoonosis ( virus que logra transmitirse desde animales a humanos ) . se sospecha de un virus que afecta a murciélagos . toca esperar confirmación . \n',
#  'people listen when user_placeholder and user_placeholder talk . my boys are wicked smart . nice piece . url_placeholder \n',
#  'poong nazeraan , please pray for us 🙇♂️🙏 url_placeholder #wuhansars #coronavirus #sars #mers #emergingvirus #zoonoses\n',
#  'my friend user_placeholder and i got some airtime today . thanks user_placeholder for the opportunity to share our thoughts . url_placeholder \n',
#  'i literally have the never ending cold . like this can chill i ’ ve been dying for too many days now 😩🤒😷 #wuhansars #coronavirus #academiclife #zoonoses\n',
#  'following are the three ( 3 ) worst things that have ever happened to me : ( in no order ) : encore closing graduating fredonia the end of vine that is all . \n',
#  'bomboclaat url_placeholder \n',
#  'chinese report says wuhan outbreak may be from new coronavirus url_placeholder \n',
#  'hello everyone ! our lucas project is doing far better than we ever anticipated and we are so thankful to everyone who has helped donate so far ! these are the koalas we adopted ! all future donations will go towards rescuing other koalas as well as helping the fire rescue service url_placeholder \n',
#  'china confirms new coronavirus as it investigates mystery wuhan illness url_placeholder \n',
#  'mainland media say preliminary lab results show the wuhan pneumonia outbreak is being caused by a new type of coronavirus . url_placeholder \n',
#  'wta players in shenzhen beware . wuhan is a 4.5 hours high speed train ride from shenzhen ... #hongkong\n',
#  '15 patients tested positive for the new strain of coronavirus ( the same virus family that sars and mers belong to ) . eight have been discharged from hospital . wuhan authorities say that there is no evidence of human-to-human transmission . story here : url_placeholder \n',
#  'aaand did this applies here too : i created this video with content by user_placeholder who hails from the former soviet union . to earn her degree in literature , she was required to take a course in combat propaganda aka url_placeholder \n',
#  '.user_placeholder ( translated ) : new preliminary ruling on unexplained in url_placeholder url_placeholder #psyops #mindwar #dontbeapawn\n',
#  'hmmm the phlegm that i coughed up this morning had a little bit of blood in it lol um wow i ’ m actually dying from the bushfire air quality 😍 #coronavirus #pneumonia #wuhan\n',
#  'authorities in beijing are battling what may be a new strain of pneumonia after 59 people contracted a mysterious respiratory illness in central china . journalist patrick fok reports url_placeholder \n',
#  '📍dosan bunsik 10-6 dosan-daero 49-gil , sinsa-dong , gangnam-gu , seoul , south korea 200106 mono tube mingyu , the8 , vernon url_placeholder \n',
#  'coming out january 22nd url_placeholder url_placeholder #3\n',
#  'words have never been more powerful than they are now \n',
#  "user_placeholder she removes eggs from either end of the egg carton , so eggs are left only in the center . i move all the eggs to one end , so when you grab the front of the carton , you 're holding the center of gravity . we have silently been moving eggs back and forth in the carton for years . \n",
#  'looks like another strain of coronavirus is on the loose . \n',
#  "as the government goes back to court to try to resurrect its mask ban , civic party lawmaker dennis kwok points out that people are rushing to buy masks so they do n't fall victim to the wuhan virus outbreak . url_placeholder \n",
#  'uhs handmade coffee mugs still available . get yours ... $ 20 . retweet ! ! venmo user_placeholder user_placeholder user_placeholder user_placeholder url_placeholder #hongkong\n',
#  'i have 10 hobbies i do once a month . here ’ s a cool picture.😂 url_placeholder \n',
#  'jonbenét wasn ’ t a sacrifice at all , she was a spell cast over all of us . a composite of purity and light , developed and deployed in the dark . every detail of this case seems to evokes pain , suffering , disgust — our most powerful , draining , negative emotions . this is by design . url_placeholder \n',
#  'user_placeholder our information suggests that the original rumors of a coronavirus originate from a commercial lab that tested samples and leaked the sequences before dec. 31st . we heard that labs had full genome by jan 1st , but of course , these are unsubstantiated.. \n',
#  "what a wierd start to the decade , almost ww3 , a international fugitive escape , an air disaster , bush fires , royals who dont want to be royals , musk dancing on stage in china , and it 's only day 9 . \n",
#  'juan de los muertos it is . my syllabus needs more zombies . thanks for all the suggestions , i can ’ t wait to teach them in future semesters ! #2020sofar\n',
#  'wuhan city yesterday url_placeholder \n',
#  '`` le nouveau trouvé dans la pneumonie à semble être beaucoup moins grave que le qui cause le ou le selon un professeur de médecine respiratoire chinois . url_placeholder url_placeholder \n',
#  "user_placeholder user_placeholder our sources suggested a coronavirus with sequence `` 80 % similar to sars-cov '' , but it 's unclear whether that 's a specific gene or the whole genome . #chine #coronavirus #wuhan #virus #sars #mers #china\n",
#  'chinese state-run media cctv said that a laboratory has confirmed the mysterious found in is a new type of coronavirus . url_placeholder \n',
#  'what a year ! #chinesepneumonia #wuhan\n',
#  'hong kong expert urges mainland china to publish the genetic map of wuhan pneumonia ( coronavirus ) as soon as possible so a rapid test can be developed . url_placeholder h/t pathfinder \n',
#  '哈哈哈，这么帅的直男肯定出轨 被老婆当场抓住，真刺激 谁还有这种出轨被抓的视频，一起分享分享 url_placeholder \n',
#  'this is the stuff i probably should do once in awhile but like if you don ’ t tell me you want to do something before i get home from work/school there ’ s about a 0 percent chance i ’ m going . \n',
#  'this summer is shaping up nicely ... red hot chili peppers , green day , fall out boy , the interrupters , journey , chicago , rick springfield , black crowes ... \n',
#  'url_placeholder \n',
#  "a thing to normalize in 2020 : not travelling . some people are not physically able to , some people can not afford to , and some just literally do not want to . besides , it 's not very environmentally friendly . stop telling people to `` get out there '' or `` anyone can travel the world '' . \n",
#  '⚠💉 la infección se confirmó por primera vez el 31 de diciembre en wuhan , una ciudad del centro de china . url_placeholder \n',
#  'pro/ah/edr > undiagnosed pneumonia - china ( hu ) ( 07 ) : official confirmation of novel coronavirus url_placeholder \n',
#  "my 2020 vision this year is , instead of having 🌎 currently in : __ ( name of a place i really wan na travel to ) i wan na make it based in : ___ ( name of a place i really wan na travel to , and stay there 5ever ) on my socials . i 've been saving moonies ! ! *fingers crossed* \n",
#  "hello , my name is farren , and it 's time for a new pinned tweet for 2020 ! i do art and talk about pirates and paranormal stuff and sometimes put scary pictures on your twitter feed on accident because twitter likes to show peoples ' likes . following will be links pertaining to me url_placeholder \n",
#  'china confirms new coronavirus causing “ pneumonia ” comes from a genetic variant of the same strain that produced the sars epidemic | south china morning post url_placeholder \n',
#  'user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder fmji , nri & residents be allowed to open foreign ( major ) currency accs savings , current ac in our banks to enable instant free fund transfers with inv option in the same currency bringing large inv by🇮🇳s saving bank fees & ⬆️psb fc dealings hsbc has global ft opn url_placeholder #china #hongkong\n',
#  "a mysterious illness has infected 51 people in wuhan , china `` dozens of people have been treated for a mystery illness in wuhan , including several in critical condition . '' `` a new can not be excluded , '' the who said in a statement . url_placeholder #budget2020\n",
#  'no offense but getting into a nursing program in fall 2020 would really suck #epidemic #coronavirus\n',
#  'the virus that caused a recent pneumonia outbreak in wuhan city was identified as a new type of coronavirus . researchers have successfully obtained the genetic sequencing of the virus from one patient and verified 15 patients infected with the virus : cgtn url_placeholder \n',
#  "just watched a fascinating show on biblical signs and the coming apocalypse that will be triggered by the full solar eclipse ... of 2017. it was really good , lots of interesting info . i 'm sure they just miscalculated . it happens . \n",
#  'idk url_placeholder \n',
#  'china confirms new as it investigates mystery illness url_placeholder \n',
#  "i ca n't believe this is actually happening #coronavirus #wuhan #pneumonia\n",
#  'mk yo creo que del 2020 no pasamos jsjsjs \n',
#  'a preliminary investigation into viral pneumonia illnesses sickening dozens of people in and around china identifies the possible cause as a new type of coronavirus , state media says . url_placeholder \n',
#  '59 people have been sickened in wuhan , and possible cases have been reported in hong kong and south korea url_placeholder \n',
#  'as hk has seen up to 38 citizens infected by the novel corona virus like sars from wuhan , the city is running out of mask n saline by both panic purchases n supply ban from china , price soar up to 10 times higher than usual . this also happens in macau . \n',
#  'this is it . this is the one . #soshk #chinesepneumonia\n',
#  'i really want more people to see this video of my boyfriend ’ s step dad manhandling a newborn baby goat and then dropping it on it ’ s head because i laugh hysterically every time i see it . url_placeholder \n',
#  'coronavirus ? sign me up user_placeholder \n',
#  'you cant have the olympics unless you discriminate by race \n',
#  '🇨🇳 neue details zur rätselhaften lungenkrankheit von mediziner haben bei mehreren der erkrankten ein neues corona-virus identifiziert url_placeholder \n',
#  '20191123 wuhan fm say it真实谎言—winwin focus cut loyalchoc🍫for winwin url_placeholder #china #wuhan\n',
#  'yikes #董思成 #winwin #윈윈 #ウィンウィン #wayv #weishenv #威神v\n',
#  'wuhan , a mega city in central china , is grappling with a mystery pneumonia may have spread to hong kong . dozens of sick travelers returning to hong kong from wuhan have caused a run on face masks . url_placeholder \n',
#  'suicidal people during ww3 url_placeholder \n',
#  'film - rumoured cast - synopsis - sequel to the 2018 film ( starring and and will depict a pair of siblings ’ relationship url_placeholder \n',
#  'wuhan bbt medicals is heading for the arab health 2020 , our showcase is at sam 51 in the dubai world trade centre , dubai , uae . url_placeholder #gobrother2 #huxianxu #dengenxi #gobrother #zhangzifeng #pengyuchang #快把我哥带走2\n',
#  'steel industry could be seeing a recovery but things not looking great for graphite electrodes heg & graphite india higher today but fundamentals not looking too bright kotak says *4qfy20 ge prices -20-25 % qoq margins *fy2019 60 % *1hfy20 20 % *3qfy20e could fall to 0-5 % #arabhealth #exhibitions #wuhanbbt #dubai\n',
#  'user_placeholder this from user_placeholder is gold ! is a lie ! ! url_placeholder \n',
#  'so $ btc is cool and all , but it ’ s stable and boring for now ( a good thing ) . i needed some more excitement . surely i can ’ t be the only one geeking out over the new upside down fruit bat quarter release that ’ s coming out next month ? url_placeholder #arsonemergency #climateemergency #climatedenial #australianbushfiresdisaster #auspol\n',
#  "le sujet des à devient l'enjeu principal des municipales . pour cause , on estime à 5 millions de rats présents dans la capitale . url_placeholder url_placeholder #nerdalert\n",
#  'wuhan pneumonia : asia battens down for chinese new year rush url_placeholder #rats #paris #dératisation\n',
#  'my mp user_placeholder voted against allowing children to be reunited with their parents . she ’ s an nhs doctor . a consultant . a paediatrician . \n',
#  "the government appears to think that expanding means-tested supplementary payments that tie families in knots and traps them mercilessly in poverty is the way to address severe hardship . budgeting services do n't have the answers . url_placeholder \n",
#  "it 's related to sars . scientists have discovered a new coronavirus in patients with url_placeholder ht user_placeholder \n",
#  "random : in'mate , n. [ in or inn , and mate . ] a person who lodges or dwells in the same house ... ( url_placeholder \n",
#  'a preliminary investigation into viral illnesses sickening dozens of people in and around has identified the possible cause as a new type of url_placeholder #wuhanpneumonia\n',
#  'chinese authorities have made a preliminary determination of the cause of in wuhan as a novel ( new ) user_placeholder continues to monitor the situation closely and is ready to support to investigate and respond to this outbreak . url_placeholder ( 1/7 ) #1828 #inmate\n',
#  'make we believe in our continento make badguysz no hijack am finish url_placeholder user_placeholder user_placeholder user_placeholder url_placeholder #pneumonia #wuhan #china #coronavirus\n',
#  'chinese authorities have made a preliminary determination of a novel ( new ) as the cause of the current cluster of pneumonia cases in wuhan , read more here ⬇️ url_placeholder #pneumonia #coronavirus #china\n',
#  'and here we are 👇🏻 official statement user_placeholder url_placeholder #ibelieveinafrica #newsingle #evergreen #timelessmusic #newyearsong #inspiration #ageless #twoweeksold #demoz #ibelieveinafricatshirtsavailable\n',
#  'new identified in 15 out of 59 suspected cases in ( via user_placeholder #coronavirus #china\n',
#  'cough , sore throat , fever ... should i phone 111 ? 🤣 see if they send me an ambulance for chest pain 😏 #wuhan #coronavirus\n',
#  'damn today could be my last day on earth and i still haven ’ t seen alessia cara in concert . i got ta change that #coronvirus #pneumonia #wuhan\n',
#  "this new virus has caused severe illness in some patients . so far the wuhan cluster has seen more than 50 people sick . scientists say they 've ruled out a virus exactly like sars because this virus does n't appear to pass easily from human to human . \n",
#  'china has identified a novel as the cause of a mystery outbreak in the city of wuhan that infected 59 people . 15 patients in had tested positive for the virus , which showed “ typical coronavirus morphology ” . url_placeholder url_placeholder \n',
#  'there ’ s no evidence that the virus , a coronavirus , is readily spread by humans , and it has not been tied to any deaths . but health officials in china and internationally are watching it carefully . url_placeholder #china\n',
#  'china identifies new strain of coronavirus as source of pneumonia outbreak url_placeholder #coronavirus #pneumonia #wuhan #wuhanpneumonia\n',
#  'some of this is coming this year👀 url_placeholder \n',
#  'nearly 60 people in wuhan , china , are infected by a mysterious respiratory virus . the nature interviewed three international virologists , including dr. seungtaek kim , head of zoonotic virus lab of institut pasteur korea , for their views on the illness . url_placeholder \n',
#  'chinese government scientists have identified a new coronavirus as the cause of a mystery pneumonia outbreak in wuhan url_placeholder url_placeholder #2020\n',
#  'public announcement url_placeholder \n',
#  'eine mysteriöse lungenkrankheit breitet sich in der zentralchinesischen metropole wuhan aus . wissenschaftler meinen nun den verantwortlichen erreger gefunden zu haben : ein neuartiges coronavirus . url_placeholder \n',
#  'it is official : new coronavirus detected in 15 pts in the wuhan outbreak . entire genome sequence obtained ( deposited where ? ) . no mention yet of name ( wars/wers-cov ? ) . diagnostic pcr primers coming soon ( i hope ! ) url_placeholder \n',
#  'user_placeholder user_placeholder user_placeholder is there going to be a venn diagram in this thread ? they are just the best . url_placeholder \n',
#  'a lot of work to do with this : diagnostic test development ( and make it internationally available asap ! ) , search for the reservoir , receptor use , cellular target , affected body sites ( upper/lower respiratory tract , shedding in urine , stool ? ) , effectiveness of drugs ... url_placeholder \n',
#  'okay so a thread on the role of different countries during \n',
#  'user_placeholder user_placeholder user_placeholder no but here is a scatter graph url_placeholder #coronavirus\n',
#  'chinese authorities have made a preliminary determination of a novel identified in a hospitalized person with pneumonia in wuhan . chinese investigators conducted gene sequencing of the virus , using an isolate from one positive patient sample . url_placeholder #worldwar3 #iranvsamerica #trumpswarofmassdistraction #thursdaymotivation #pakistan #israel #india #indiasupportscca #us #iraq #wwiil #iranattacks #iran\n',
#  'moving to a bigger one this 2020 para lets go 🏡🙏🏻 \n',
#  'now we can say : is the cause of in linked to url_placeholder user_placeholder user_placeholder user_placeholder user_placeholder url_placeholder #coronavirus\n',
#  'user_placeholder cam buto url_placeholder \n',
#  'registration currently open for user_placeholder masters in surgical science ( mchsc ) , starting oct 2020. a part-time , blended online 2yr course , suitable for registered medical practitioners in full-time employment , run by a multi-professional faculty . apply early ! url_placeholder #a_novel_coronavirus #severe_viral_pneumonia #wuhan #china #seafood_market #coronaviruses #coronaviridae #emerging_viruses\n',
#  'is used in synthetic indigo and certain pharmaceuticals . and its primary use is in the manufacturing of the methyl , ethyl , and benzyl esters for the perfume industry . wuhan landmark is a professional manufacturer & supplier of cinnamicacid url_placeholder \n',
#  '🇨🇳 alerte sanitaire - un inconnu affecte des dizaines de personnes à ( centre de la 59 malades de inconnue ont été traités , 165 personnes suivies . aucun décès mais 7 personnes sont dans un état critique . des seraient responsables . ( cnn ) \n',
#  'god i have not been this sick in a hot minute #cinnamicacid #104 #flavorings\n',
#  '18:12 10 more people have pneumonia symptoms after travelling to total number of cases reaches 48 in hong kong . url_placeholder #virus #wuhan #chine #pneumonie #animaux\n',
#  "le virus de pneumonie a maintenant été identifié . le dernier bilan officiel de l'épidémie de wuhan fait état de 59 personnes contaminées ( pour aucun décès ) > url_placeholder \n",
#  "all you have to do is wait for resources to get so scarce the poor people will kill each other off , and you can convince killing off the `` useless '' stragglers is for the greater good . #wuhan\n",
#  '“ it ’ s bullying , and there ’ s underlying racism in there ” youtuber and cultural commentator user_placeholder says the public has pushed meghan and harry into stepping down from royal life url_placeholder url_placeholder \n',
#  '2020 the girl is focused , nothing can disturb the girl url_placeholder \n',
#  'tickets for all dates on our china + japan tour are now up on user_placeholder eazy peezy ✌🏼 url_placeholder url_placeholder #victorialive\n',
#  "i see no reason to not keep posting this until the media actually gets an answer as to why these were n't arranged in may . url_placeholder \n",
#  "walls : cupsleeve and listening party join us as we celebrate louis ' new album . there will be , games , raffles and special goodies to be given away by the team ! no entrance fee ! register now to get your freebies reserved ! url_placeholder url_placeholder \n",
#  'there ’ s a mysterious new outbreak in china , but how are outbreaks of such as this detected ? find out more in our research article url_placeholder \n',
#  'and well done tiarnan , sean and all at barna greenway for your absolute dedication and persistence 🙌 delighted to have played a part in getting this across the line . user_placeholder #ltph2020 #wallsph\n',
#  'un ’ epidemia di polmonite in cina potrebbe essere stata causata da un virus simile a quello della sars url_placeholder #pneumonia #infectiousdisease\n',
#  'byulharangs ! i will be holding a birthday fanmeeting on february 8 , 2020 at 6pm kst ! for byulharang 1st gen presale : jan. 15 , 2020 at 8pm to 11:59pm kst for general sale : jan. 17 , 2020 at 8pm you can purchase the tickets through melon ticket ! see ya soon . 🌠 url_placeholder \n',
#  'apple recycles your smartphone , even if it ’ s not an iphone . \n',
#  'mystery china virus is from same family as sars , scientists say url_placeholder \n',
#  'chine : l ’ épidémie de pneumonie serait due à un coronavirus encore inconnu url_placeholder \n',
#  "mystery illness in wuhan 'caused by coronavirus ' url_placeholder \n",
#  'this year ’ s summer has to be in 🇬🇧🇺🇸🇧🇧🇲🇺🇪🇸🇮🇹🇬🇷 ... ... ... ... .. ? ? ! url_placeholder \n',
#  "time ’ s new cover : “ we 've upped the ante. ” why nancy pelosi is going all in against trump url_placeholder url_placeholder \n",
#  'chicken wings can cure anything \n',
#  "a new strain ? 'mystery ' pneumonia outbreak in china could be linked to “ it ’ s hard to know how severe a new infection is , because you only see the cases that are severe enough to be detected . '' user_placeholder comments in user_placeholder 👇 url_placeholder \n",
#  'user_placeholder to learn about see : url_placeholder it has : ● accurate intro climatology info ● in-depth science from both skeptics & alarmists ● links to balanced debates between experts on both sides ● info about climate impacts ● links to best blogs on both sides \n',
#  'day 40 of of : performing dances around the world `` trickeration at the user_placeholder `` ... url_placeholder #coronavirus\n',
#  '4th qtr dapat honor na self ha ? ? pa manila pa ta balaa 😖😖🤞🤞 #climatechange\n',
#  'entre quatro cachorros e dois gatos não tem como saber quem é o assassino posso excluir dois , mas só url_placeholder #100days #norma100 #normamiller #lindyhop #solojazz #jazz #dance #trickeration #normamiller #elbtunnel #submarine\n',
#  'researchers in china have identified a new as the pathogen behind a mysterious that has sickened 59 people in and caused a panic in the central chinese region . they detected this virus in 15 of the people who fell ill. url_placeholder url_placeholder \n',
#  "here 's our report for user_placeholder showing earthquake damage inside costa sur power plant in southern puerto rico . the operations manager of the plant predicts he can get the plant up and running in a month . the ceo of puerto rico 's electric power authority says it 'll be 1yr . url_placeholder \n",
#  "big announcement : cso awards are coming to the uk ! url_placeholder we 're celebrating 30 of the uk 's leading cybersecurity execs for their great work . know a cso , ciso , or other security lead doing amazing work ? nominate them , or tell them to put themselves forward ! #coronavirus #pneumonia #wuhan\n",
#  'appreciate the temple for buying the cow and showing humanity . user_placeholder user_placeholder \n',
#  '$ atto shareholder meeting set for feb 4 to authorize the company to buyback up to 30 % of the share capital over the next 5 years at up to a 50 % premium ( or a 50 % discount ) to the share price average over 10 days preceding the offer . \n',
#  '[ thread ] sac ali express ! #chinese #buddhist #bananimalslaughter #india #srilanka #lka #animalrights #animalcruelty #banslaughter #china #animalliberation #animalwelfare #animallovers\n',
#  'the craziest fact about is that suspected cases are only reported in hong kong , macau , taiwan , singapore , south korea and wuhan . the only chinese city with is hong kong & wuhan are ~900km apart ; no one was infected between this 900km ? url_placeholder \n',
#  'user_placeholder url_placeholder \n',
#  'don ’ t miss it ! ! ! 1 march 2020 at user_placeholder special guest star user_placeholder ! user_placeholder user_placeholder user_placeholder 🎸 🎶 url_placeholder #wuhanpneumonia #wuhanpneumonia #wuhan\n',
#  'who says the pathogen behind pneumonia outbreak in wuhan may be a new coronavirus -- the family linked to sars & mers . the race is on to develop diagnostic tests , discover the animal reservoir ( s ) , define the incubation period , clinical spectrum & treatment . url_placeholder \n',
#  "a new virus related to sars is the culprit in china 's mysterious pneumonia outbreak , scientists say url_placeholder \n",
#  'public health agency of canada warning travellers to china to avoid contact with animals , farms and live animal markets in the wake of a cluster of pneumonia-like illnesses of unknown cause . some cases work at a seafood market in wuhan city url_placeholder \n',
#  "donald trump : `` and again , tucker 's been very good , i have to say , he 's been good . smart . he 's been great , tucker . '' date : oct. 10 , 2019 ( h/t user_placeholder url_placeholder url_placeholder #wuhanpneumonia\n",
#  'about the novel 2019 coronavirus category url_placeholder \n',
#  "user_placeholder a new virus ? okay i usually start in china with most of my infections ... “ wuhan pneumonia outbreak : mystery illness 'caused by coronavirus ' ” url_placeholder \n",
#  '1 ) 感染症 と ２）５g 関係ないとは言い切れない。電磁波で、免疫機能は低下するから。だから、＃５g反対 1 ) 新型コロナウイルス検出＝原因不明肺炎で中国 url_placeholder ⇒湖北省武漢市で、感染症多発 2 ) 武漢市は中国初の5gネットワークの試行都市 url_placeholder 2019/５/11 \n',
#  "newly appointed georgia senator kelly loeffler will sit on the agriculture committee , where she will oversee her husband 's company . url_placeholder \n",
#  'hit up cassidy for any beat inquires 😂😂😂 url_placeholder \n',
#  'budget live : watch as the announcements take place & find out how the changes will impact you or your business url_placeholder \n',
#  'two most recent democrat potus vs republican potus url_placeholder \n',
#  'president cyril ramaphosa 🇿🇦 president donald j. trump 🇺🇸 dreamt you discussing about me last night . \n',
#  'maging barista sa starbucks ang gusto kong gawin sa summer 😊 no joke \n',
#  '….a company called cambridge analytica has activated an invisible machine that preys on the personalities of individual voters to create large shifts in public opinion…… ... 20/ \n',
#  '“ un equipo de científicos chinos descubrió que el misterioso brote de neumonía viral en wuhan en china es causado por un nuevo tipo de coronavirus , la misma familia de virus que el síndrome respiratorio agudo severo ( sras ) . ” url_placeholder \n',
#  'here is every bit of good wrestling in 2020 , every single bit url_placeholder \n',
#  'chinese authorities have made a preliminary determination of a novel ( or new ) coronavirus , identified in a hospitalized person with pneumonia in wuhan . chinese ... url_placeholder \n',
#  'last semester of under grad ... .we going up ? or we going up ! ! ! ? ? \n',
#  'regime - `` new type of believed to behind outbreak - cases of viral pneumonia increase in province - believe linked to exposure to seafood and animal url_placeholder \n',
#  "1. the world has been waiting for more word from about the cluster at a bunch came out late last night . official confirmation they 've sequenced a full ( ! ! ! ) & found evidence of it in 15 people . url_placeholder \n",
#  "2. key questions now : how did the new jump to people ? from what species ? how broadly is it found in that species ? and are animals infected with it found in other markets ? ca n't assume that one seafood market would be the the sole transmission location . \n",
#  'venga lo curo mi amor 😏 url_placeholder #communist #china #coronavirus #pneumonia #wuhan #hubei\n',
#  '2020 birthday project part1 in china beijing\\hangzhou\\qingdao\\wuhan\\guangzhou\\shenzhen\\dongguan 北京\\杭州\\青岛\\武汉\\广州\\深圳\\东莞 cafe support 咖啡厅应援 url_placeholder #china #pneumonia #wuhan #coronavirus\n',
#  'at first i was like ... then i was like ... url_placeholder #coronavirus #wuhan\n',
#  'cuando nos veamos los mutuals de twitter en la firma de libros de argentina de los compas url_placeholder \n',
#  "two things of note in this statement : who 's strong endorsement of china 's capacities to respond to this outbreak and it 's unqualified recommendation that countries should not implement travel/trade restrictions . url_placeholder #방탄소년단 #민윤기\n",
#  'user_placeholder oops , i misstated it . i have no qualm of ceos not even issue guidance at all . however , if they issue some guidance , they need to state why their guidance was not ok. if $ bbby guide was from previous admin , the ceo should distance it from the get-go . the ceo was busy firing ppl ... #iranvsamerica\n',
#  'thanks to the hard-working men and women of aston , brookhaven , nether providence , ridley and swarthmore police departments ! we appreciate everything you do to keep our communities safe . url_placeholder \n',
#  'new research finds jupiter is flinging asteroids at earth url_placeholder url_placeholder \n',
#  'china says outbreak due to new type of url_placeholder via user_placeholder \n',
#  'der auslöser der mysteriösen in ist gefunden : ein bislang unbekannter erreger aus der familie der soll die schwere atemwegserkrankung bei fast 60 menschen in der millionenstadt verursacht haben . url_placeholder \n',
#  'me returning to the streets url_placeholder \n',
#  'exclusive : environment secretary theresa villiers tells user_placeholder that chlorinated chicken and hormone-treated beef will not be allowed in the uk and she would ‘ hold the line ’ in us trade negotiations ... more on user_placeholder bbc1 , 26th january url_placeholder #pneumonia #coronavirus #wuhan\n',
#  'epidemics of diseases known and unknown are one of our greatest global health threats ; threats that are with us constantly . a cluster of patients with an unusual respiratory infection is , and should always be , a worry . #lungenkrankheit #china #coronaviren #wuhan #wissen\n',
#  'hankou customs house , one of the social gatherings , collected wuhan ’ s wishes to 2020. also , various events will be held in wuhan such as light show or hearty soup festival . the celebration will last to the chinese new year . url_placeholder \n',
#  'pepper hamilton and troutman sanders ( user_placeholder have agreed to merge effective april 1 , 2020. troutman pepper will offer expanded capabilities and practice strengths , with a hallmark focus on client care . url_placeholder #countryfile\n',
#  'illegal somali immigrant arrested for sex crimes against children in houston url_placeholder plz support .user_placeholder 4 re-election & lauraloomerforcongress please retweet \n',
#  'hey so i ’ m starting commissions ! please pm me for details ! thank you for your support ! url_placeholder #visitwuhan #explorewuhan\n',
#  'オーストラリア山火事コアラ url_placeholder \n',
#  'never forget that some arsenal fans wanted jose mourinho because he provided some basic analysis of our front three on sky sports . url_placeholder \n',
#  'i need lime scooter and white claw weather \n',
#  'our new ad reminds viewers that trump believes a war with iran advances his own re-election . if trump knows that voters are aware of his motives , his incentive to bring us into a disastrous war goes down . url_placeholder #prayforaustraliafromjapan #australiafires #prayforaustralia\n',
#  'the answer ... ... . url_placeholder \n',
#  "this march , comedy icons steve martin & martin short are bringing you the funniest show in town ... at the moment ! see them live for the first time in the uk at london 's user_placeholder and in glasgow . tickets available at : url_placeholder user_placeholder url_placeholder \n",
#  'realestate vs mutual fund vs quality stock url_placeholder \n',
#  'how to do courses on coursera and earn certificates for free . url_placeholder is an online platform that enables one to build skills with courses , certificates , and degrees online from world-class universities and companies . #cdnelearning #elearning #edtechchat #edtech\n',
#  'stock market at all-time high ! how are your 401k ’ s doing ? 70 % , 80 % , 90 % up ? only 50 % up ! what are you doing wrong ? #martinshort\n',
#  "our world will destroy when the last drop of `` love '' will extinct . remember this line . destruction ai n't so far.🔥 \n",
#  ".user_placeholder announces three criminal justice goals : -end cash bail system -divert low-level drug crime punishment to drug rehab -reduce `` excessive length of stay in prison '' including mandatory sentencing url_placeholder \n",
#  "`` what 's going on with this license ? '' `` [ redacted ] is listed as using it '' `` can you remove them ? '' `` pretty sure they need to log off '' `` all right , i 'll reach out to local it to do it , they passed away on christmas '' `` i 'm so sorry but what '' \n",
#  "user_placeholder user_placeholder user_placeholder a team of lawyers from the conservative federalist society , organized by kellyanne conway 's husband george conway , have formed a group dedicated to highlighting the trump administration 's perceived flouting of constitutional and legal norms👉overlap 🤔 url_placeholder \n",
#  '| el ministro de salud , dr. aníbal cruz , se reúne con el gobernador de user_placeholder para analizar las acciones que refuercen la atención médica en este departamento . url_placeholder \n',
#  "with all this money around , i 'm requesting a tv show or miniseries about the spanish flu of 1918-1920 ( supposedly so named because media in countries involved in wwi were n't allowed to report fully about the severity of the pandemic , but they could in neutral spain ) url_placeholder #talesfromthetechtrenches\n",
#  'greetings from the wuhan city . china 🇨🇳 0 degree is very cold user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder url_placeholder \n',
#  'agreed #ahora #lapaz #creandolazossaludables\n',
#  'meet best foods vegan , the plant-based spread with a delicious , creamy taste . \n',
#  'the user_placeholder announced these new fruit bat quarters arriving this year . cause i always wanted to be more goth while paying parking meters url_placeholder \n',
#  'american horror story vient d ’ être renouvelée pour 3 saisons ( jusqu ’ en 2023 ) sur fx . url_placeholder \n',
#  '3 hours of sleep because i couldn ’ t stop coughing and it ’ s hella hard for me to breathe ? nice ! \n',
#  'flu cases are rapidly increasing in the u.s. and around the world . keep your office free of the flu by using an epa-registered disinfectant . tomi recently used steramist throughout their u.s. corporate office to prevent the spread of the flu . url_placeholder \n',
#  'beginning of the new \n',
#  'rant : if you are a liberal , progressive , or democrat , and you are amplifying or financially supporting the lincoln project pac user_placeholder or its founders -- > what the hell is wrong with you ? url_placeholder #info #ahs\n',
#  'bomboclaat ! ! ! url_placeholder \n',
#  'carrying you with me at graduation feezy . “ til 3005 ” written on my cap . #steramist #flu\n',
#  'coronaviruses are a large family of viruses that are known to cause illness ranging from the common cold to more severe diseases , such as middle east respiratory syndrome ( mers ) and severe acute respiratory syndrome ( sars ) url_placeholder \n',
#  "re-upload . this me . never give up on your passion/happiness . but there 's more to me than a dude with missing fingers . join me in my journey . user_placeholder user_placeholder user_placeholder url_placeholder \n",
#  'trump and the whole campaign team appears to be heading to palm beach — where mar-a-lago is — for a spring donor retreat . url_placeholder \n',
#  'an emerging infection cluster in china . pneumonia of unknown cause in china - watch - level 1 user_placeholder url_placeholder \n',
#  'some coronaviruses cause less-severe disease , some more severe . some transmit easily from person to person , while others don ’ t . url_placeholder #coronavirus\n',
#  "holy shit . lem me paraphrase this textbook paragraph : oppressed groups are like the miners canary . they signal when the atmosphere is toxic . we should n't try to fix the bird or blame the canary for the environment , but rather fix the environment before it hurts everyone . \n",
#  'a day in the walk of an warrior ... our gov ’ t has left us to figure things out on our own . every 3 months we flock to some corner of the world for stem cells & take supplements . why ? to stay alive . knowing there are viable treatment options & nothing is being done is shameful ! url_placeholder \n',
#  "`` tanto em 1820 como em 1920 houveram surtos de pragas '' 2020 : `` doença secreta em mg '' eu : url_placeholder #coronavirus #infectiousdiseases\n",
#  'tell congress : ban factory farms ! url_placeholder #coronavirus\n',
#  'user_placeholder delighted to meet the nurses of our future in donegal today with their clinical placement coordinators user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder url_placeholder \n',
#  'recovering from serious illness caught during cruise . ( user_placeholder woz home in los gatos , ca ) url_placeholder \n',
#  'a novel is a new strain of the virus that has not been previously identified in humans url_placeholder #op1 #vuurwerkoverlast #vuurwerkverbod #ambulance #opvoeding\n',
#  'last semester of college time to fk shit up \n',
#  'novel coronaviruses emerge periodically , as we have seen . sars emerged in 2002 and mers emerged in 2012. several known coronaviruses are currently circulating in animals that have not yet infected humans . url_placeholder #als\n',
#  'asda shoppers furious after stores run out of chicken url_placeholder \n',
#  'मुझे गर्व है कि मैं सेकुलर नहीं एक ऐसा हिन्दू हूं जो सिर्फ हिन्दुत्व को सपोर्ट करता हूं user_placeholder \n',
#  'is wuhan pneumonia linked to porcine respiratory coronavirus ? is that the pork connection in the wuhan market ? url_placeholder #nurse2020 #internships #luh\n',
#  'our registration form has been submitted by user_placeholder on behalf of the 3 cochairs user_placeholder & vicechairs user_placeholder user_placeholder & user_placeholder & all members . so as soon as we hear back we ’ re officially an operational appg again on the \n',
#  'user_placeholder user_placeholder look out georgia url_placeholder #coronavirus\n',
#  'feel the power , precision , and clarity of soundform elite as you enter our booth . url_placeholder \n',
#  'sathana url_placeholder \n',
#  "china 's new virus looms over lunar new year travel url_placeholder \n",
#  "hey there 's a new sars/mers-like virus spreading in china , which is super fun . url_placeholder #coronavirus\n",
#  'maybe we can get to number 1 in china too . url_placeholder \n',
#  'as surveillance improves around the world , more coronaviruses are likely to be identified . url_placeholder #proud_hindu_hindutwa\n',
#  '¿qué son los coronavirus y por qué se han transformado en una amenaza para el ser humano ? url_placeholder url_placeholder \n',
#  '`` richmond , long known as a sleepy capital steeped in confederate history , has morphed into a dynamic cultural center on the cutting edge of the arts , food and recreation. ” our city ’ s one of the top 50 places to visit in . the . world ! url_placeholder \n',
#  '6. how was 2019 for you ? #mikepenning #loancharge\n',
#  '35. if you could get rid of one thing in this world , what would it be ? \n',
#  'this year i ’ m not waiting on anybody ! ! ! keep up or get left behind . i lost too much time last year waiting for proposals and music and visuals and all that jazz . this year ? deliver or get dropped ! #ces2020 #revolutionarysound\n',
#  'between 31 dec and 5 jan , 59 pneumonia cases possibly associated with a novel coronavirus have been reported in wuhan city , china . for ecdc ’ s threat assessment and options for response , see url_placeholder \n',
#  'hey man make sure yall hit up cassidy if yall need some beats 😂💀💀💀💀💀 url_placeholder #wuhan\n',
#  'if i had the remote from adam sandler ’ s ‘ click ’ , i would simply fast forward to march 20th , 2020 and receive my preorder of animal crossing : new horizons \n',
#  'i ’ m so grateful for this opportunity and i can ’ t believe i ’ m able to do this because it ’ s expensive and i know how privileged my family and i are to be able to afford such a trip . nearly crying because wow that will be my first time in the us and my second time outside of europe #comeoutyeblackandtans\n',
#  'by the end of 2020 bitcoin will be between $ 15,000- $ 20,000 . according to user_placeholder currency strategist for user_placeholder who all the way back in december 2018 managed to predict the end of 2019 price , almost exactly on the money . 💲 we ask him to do it again : url_placeholder url_placeholder #coronavirus\n',
#  "the phrase `` a new coronavirus '' should spark more worry than any political blather ever does . \n",
#  'acting like i couldn ’ t do this shit , just call me user_placeholder 🤧url_placeholder #competitive #1rva\n',
#  '1/ china , ciudad de wuhan 🇨🇳⚠️ enfermedad respiratoria aguda asociada a un nuevo agente infeccioso 😷 ➡️59 casos confirmados 🏥 ➡️0 muertes ☠️ ➡️+150 contactos bajo vigilancia 🔎 hilo url_placeholder \n',
#  "🚨breaking🚨 : reporters try to interview soleimani 's grieving widow and she assaults them ! the religion of peace ? url_placeholder \n",
#  'i ’ m ready for summmerrrr 💛🌞 \n',
#  'during an outbreak , movement of people can make it challenging to track infected or exposed people and stop the spread of disease . learn how officials in uganda studied population movement to prepare for more user_placeholder url_placeholder url_placeholder \n',
#  "mexico 's popocatepetl volcano erupted with lava and rocks shooting from the crater and smoke and ash rising into the sky . read today 's top stories here : url_placeholder url_placeholder \n",
#  'my latest asia unbound blog on the growing influence of chinese state media in thailand : thailand ’ s press warms to chinese state media url_placeholder via user_placeholder \n',
#  "i ca n't wait to get a new tattoo ☺️☺️ \n",
#  'travelling to be aware of an outbreak of of unknown cause in wuhan city , hubei province . consult the travel health notice before you go & contact your healthcare provider if you feel ill after your return . url_placeholder \n',
#  'protect yourself & reduce risk from infection : 👏🏽hand hygiene 🤧cover mouth & nose when coughing & sneezing thoroughly cook meat & eggs 🌡avoid close contact with anyone with respiratory illness ❌ avoid close contact with wild or live farm animals url_placeholder \n',
#  'yo i ’ m really about to be out 😭 my birthday trip is booked ! ✈️💕 and i ’ ll be in toronto in april and then france for the summer . #garyveechallenge #youngza\n',
#  'this is my new ringtone . url_placeholder \n',
#  'have you been waiting to buy my maw masks ? well ! i finally set up shop ! get them while they last , some designs are almost sold out ! url_placeholder url_placeholder \n',
#  "the recovery of a new from patients does not mean this outbreak is over . not by a long shot ( or chalk , if you are british ) . i 've updated my today story with important observations from user_placeholder url_placeholder \n",
#  'está científicamente comprobado que con ahorras más : url_placeholder url_placeholder #ebola\n',
#  'my first book is officially published ! feel free to check it out : url_placeholder url_placeholder \n',
#  'vibez like ... 🤔🐉 url_placeholder \n',
#  'bomboclaat ? url_placeholder \n',
#  'parís , francia . fuertes disturbios tras finalizar la manifestación contra la reforma de las pensiones . hay 16 agentes de policía heridos . url_placeholder #china #pneumonia #lunarnewyear\n',
#  '2020 is my bitch #coronavirus\n',
#  'attn journalists : northwestern has launched a new digital platform that serves as a one-stop shop when you ’ re working on deadline , featuring all the tools you need to tell your story . url_placeholder \n',
#  'some news : ive been hired as the executive director of the st. louis area regional response system . the dept protects 3m+ people by working on the most complex public safety issues in the region - from terrorism to tech rescue . im joining a great team & excited to dig in . url_placeholder \n',
#  'gérard depardieu explique pourquoi il préfère novossibirsk à paris url_placeholder url_placeholder #mask #animal #costume #rave #furry\n',
#  'china identifica como un nuevo coronavirus al responsable de la misteriosa neumonía url_placeholder #coronavirus #wuhan #pneumonia\n',
#  '“ no journal will reject a paper because this sequence has been made public. ” c. drosten user_placeholder url_placeholder user_placeholder #xboxgamepassultimate\n',
#  'hopefully , the chinese release the wuhan coronavirus sequence to national epidemiology agencies asap ! “ chinese scientists obtain genetic sequence of mysterious virus , a key step in containment efforts ” url_placeholder via user_placeholder url_placeholder via user_placeholder #thedemonsrose #writerslift #writerscommunity #book #booktwitter\n',
#  '🎼 💦 🍷 ⛲️ 𝕨𝕚𝕥𝕙 🄲🄾🄳🄴🄸🄽🄴 𝕕𝕣𝕚𝕡 ˙˙˙ 💧sdıɹp url_placeholder #2020\n',
#  "the jamie heaslip podcast does n't sound that bad all of a sudden url_placeholder \n",
#  'everything is black and white to me now : on the one hand brexiter/climate change denier/anti-vaxer/football nut/tory/meghan hater/morgan/jhb/farage/hopkins and on the other : decent , non-racists . \n',
#  'here ’ s another interesting article . jt ’ s dad , pet , ruined 🇨🇦 ’ s economy for a generation . this guy is going 1 better . it will take two generations to pay off his debts . he & morneau said they would reduce the debt/gdp ratio . they even missed that benchmark.url_placeholder \n',
#  "lol at my org 's entire purpose being the reduction of carbon emissions and then sending the entire staff to ireland for a week to bond \n",
#  'every 10 years , we have the power to shape the future of our communities ! the 2020 census is just a few months away – follow us to make sure you have all the information you need to be counted . #stl\n',
#  'death anxiety is the mother of all religions , which , in one way or another , attempt to temper the anguish of our finitude . \n',
#  'two suicides in belmarsh prison in the past 2 months - well above the uk prison average . been a problem in belmarsh for more than a decade . why hasn ’ t it been fixed ? url_placeholder \n',
#  'take a sneak 👀 into our vip audio room where you can 👂 the quality acoustics of our soundform elite hi-fi smart speaker in an exclusive experience . url_placeholder #charitevirology #wuhan #coronavirus\n',
#  'currently looking for jobs after i graduate in may so if anybody wants to hire me just lmk okay thanks . p.s . i work hard \n',
#  'this energy 😩 url_placeholder \n',
#  "[ spoilers lis2 ] 58/ re : previous tweet - here are a few screenshots of stephen reynolds 's maga hat from lis2 episode 2 - rules . will continue thread shortly . many thanks to everyone who 's commented on this thread . so far , discussing > just processing alone , esp . with lis games ! url_placeholder \n",
#  "wuhan pneumonia outbreak : mystery illness 'caused by coronavirus ' - bbc news url_placeholder url_placeholder #firstdatesirl\n",
#  'world bank cuts south africa gdp forecast due to load-shedding url_placeholder via user_placeholder \n',
#  'bombooclaat url_placeholder \n',
#  'this gone be boosie , when he found out the alphas use wipe me down to scroll too 😭😭😭 url_placeholder \n',
#  "humanitarian needs in 2020 people affected : 10.6m people in need : 8.4m people in acute need : 6.2m people in need by region ( % region 's population ) somali : 39 % afar : 16 % bg : 14 % harari : 11.3 % gambella : 11 % dd : 10 % oromiya : 9 % tigray : 8 % amhara : 4.4 % snnp : 3.5 % aa : 0.03 % url_placeholder \n",
#  "congratulations , user_placeholder on expanding your historic steak house to the thriving west end neighborhood . i 'm that in addition to creating memorable experiences for people dining out , you 're also providing more opportunities for washingtonians to thrive . url_placeholder #irvinyalom\n",
#  'last day of exam bagsak kaya ulit ? #assange #freeassange #people4assange\n',
#  'facts & figures 2020 reports largest one-year drop in mortality - url_placeholder - ➤ url_placeholder url_placeholder #ces2020 #revolutionarysound\n',
#  'harry and meghan take on the global world , and i can not wait to support them through their journey that they have decided 💘 url_placeholder \n',
#  'running low on 🔋 ? our charging station is ready for your devices ! come on by ! url_placeholder \n',
#  'me🤣🤣🤣 \n',
#  'doing adult things like getting a credit card and being called for jury duty . every day of my life i get emails . please keep me in your thoughts during this trying time . \n',
#  'me da miedo que martina vaya a europa con todo lo que está pasando aunque no sea el mismo continente , pero siento q en argentina es más seguro porque lo peor q le puede pasar es el dólar o un piquete tini tini tini \n',
#  "after spending the day hoovering i 've come to the realisation i actually really enjoy it ? ? except i ca n't tell anyone bc then i 'll be asked to hoover all the time and then the novelty will wear off , instead gon na keep it secret and just hoover to treat myself every now and again \n",
#  'i am the happiest & healthiest ( minus the broken foot i suppose ) version of myself i ’ ve seen in years . what a feeling \n',
#  'for quality calendar with quality printing kindly contact us at echo prints global concept we will offer you the best and quality designs . url_placeholder #ethiopia\n',
#  'if you divide 2020 by 5 you get 404 so basically this year is an error in the matrix and doesn ’ t count . \n',
#  "i did n't think that much of the outbreak here in wuhan until i checked twitter.. now i 'm very happy i 'm leaving the city for a week \n",
#  'cole tremewan ! ! go pioneer . url_placeholder #dcproud\n',
#  'por un 2020 en donde se note el gimnasio \n',
#  'eyo , why are sooo many people sick right now . not even like ‘ m , common cold sick but like , the fucking plague sick ? ! ? hope all my friends and family get better soon , especially the ones who hadda go to the hospital . fucking crazy way to start off the new year . #cancer\n',
#  'this eagles fan is a national treasure . url_placeholder \n',
#  "bbc news - wuhan pneumonia outbreak : mystery illness 'caused by coronavirus ' url_placeholder #ces2020\n",
#  'i feel like death \n']

# %%
df = pd.read_parquet(piped_files[3])
df.head(95).cleaned_text.values
# Out:
# array(['An occasional map - 1842 [Opium War era] Map of China by its neighbour, rival, frenemy [Japan] who should know a thing or two about Qing\'s imperial geography. user_placeholder user_placeholder user_placeholder user_placeholder  "SCS belonged to China since ancient times" Xi Jinping 2015 url_placeholder',
#        'WHAT IS HAPPENING?! url_placeholder',
#        'Himchan\'s side shares "A", who is part of the current indecent assault scandal is trying to blackmail him for 100 million won A\'s side is states she only wants compensation for mental suffering, and is asking for the 100 million won as a settlement url_placeholder',
#        'user_placeholder Remember when we used to not touch stories until for precisely above-stated reasons? user_placeholder url_placeholder',
#        'Couldn’t imagine a more dysfunctional friend to complement my mess 😂😂😂 Let’s go Bruins url_placeholder',
#        'Shinjuku Awawa is a walking soap bubble who encourages the people of Shinjuku, Tokyo, to wash their hands. url_placeholder',
#        'Who is really behind sad  Did you know that leading central bankers issued a call for the same green banking system long before Greta and countless others did the same? url_placeholder url_placeholder',
#        'The Indian uncle-aunty solve a life problem with a life problem FAQ: Started working? Buy a car. On EMI. Hate your job? Buy a house. On EMI. Still unhappy? Get married, ideally to a stranger. Facing relationship issues? Have a baby. Baby is challenging? Have another. 🤦♂️🤦♂️🤷♂️',
#        'nada maaaaisss url_placeholder',
#        "I don't want to go home. url_placeholder",
#        'user_placeholder You mean GLOBAL right user_placeholder That explains this EMERGENCY Executive Order signed by you 12/21/2017 url_placeholder user_placeholder user_placeholder',
#        'The surviving 2017 Trump admin: Trump Pence Jared Ivanka Mnuchin Ross Miller Devos (Erik Prince) Chao (McConnell) Carson  With exception of Carson, this group is the heart of the rot and corruption. Their intertwined personal ties, global ties and finances tell an ugly story.',
#        'My name is Jalen, I am a young black entrepreneur. Starting my clothing brand user_placeholder Dm me for more business. 🦈 LETS GO! url_placeholder',
#        'I am going to the State Fair next year. On my momma. I ain’t missing. I haven’t been since Leah was a baby baby.',
#        'user_placeholder Bill Barr “Everyone dies and I am not, you know, I don’t believe in the Homeric idea that you know, immortality comes by, you know, having odes sung about you over the centuries, you know?” Pray he doesn’t contract a terminal disease while tRUMP is still in office!',
#        'Is MDMA addicting? No. People who use MDMA take it infrequently. Is it harmful?No, risk of harm to person taking it is low.Even less risk of harm to others! So why is black market ecstasy a problem? Harm arises from too high dose or dangerous contaminants url_placeholder',
#        'NOW. Waaaaaaaaay back in January 2009, I got swine flu. I was uninsured, under-employed, and had JUST had the Reglass Flu that past November. It was miserable and terrifying. I staggered to the ER on the third or fourth day, gasping to breathe, burning with fever, sweating.',
#        'Rebekah and Julia for Chicago west end 2020',
#        'Im a 32yr old political science graduate and i work at a newspaper writing “yarns” and I tweet things like “tremendous Friday areas, folks” with a picture of an IPA',
#        'user_placeholder Hi! As per the recent communication, we already have on-air sites in this area & with current sites prevailing too, no further coverage enhancement is currently feasible. However, we are in process to prioritize your area to ensure better coverage - Shanti',
#        'Productive day for our HOME Trial annual meeting, beautiful location user_placeholder & great research team user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder url_placeholder',
#        'Bomboclaat! url_placeholder',
#        'Contact your Ultimate Facilities Management Hub for your amazing experiences. 055 255 7664 user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder url_placeholder',
#        'Courts that will be closed for local holidays on Monday 7 October  More information: url_placeholder url_placeholder',
#        'Weekend plan: Visit Uniqlo store at Ambience Mall, Vasant Kunj. Our doors are now open and we’ve got amazing inaugural offers for you! url_placeholder',
#        'Bomboclaat? url_placeholder',
#        'The “lucky smoke” dates back to depressed Spoons staff deployed in freshers week 2019. The idea was that when you first opened a pack, you flip one cigarette over. This was to be the last one smoked from the pack, and if you lived long enough to smoke it, you were "lucky”.',
#        'Seeing Billie Eilish in July? I think so',
#        "I feel the straw that's going to break the camel’s back is Adani.  Nobody is thinking about its exposure to the banks.",
#        'The Tory Party have now clearly become the party of the aged, the rich, and the ignorant. A truly nasty party.',
#        'Thank you! Thank you! Thank you! took her first breath just this past Friday, the 27th of September 2019. We thank you for the support you gave us with our you came out in numbers to witness her and we are grateful! url_placeholder',
#        'Ownership of ones convictions holds no weight anymore when you no longer have to worry about the consequences. The importance of self will take over and fracture the needs of the many. This is the arrogance that will eventually relegate us as a foot note in time. Sad face. Poop.',
#        "'Good Listeners', the debut publication from The Common Breath publishing imprint, is now available to purchase. It is a short collection of stories by the novelist Alan Warner & The Common Breath editor Brian Hamill. url_placeholder url_placeholder",
#        'Embarrassed myself for the whole class today url_placeholder',
#        'Good morning, We here at the Institute made a tourism video to showcase all our great neighborhoods (and finally figure out this whole Frandor thing.) url_placeholder',
#        'Just goin’ on a cruise yes another one shirt Buy it now: url_placeholder url_placeholder',
#        'With trust comes peace of mind. Be like ‘Mr. Igboro’; free your mind with Airtel SmartTALK. Dial *315and enjoy calls at a flat rate of 11k/s after a N7 access fee on the first call of the day. url_placeholder',
#        'Robert Ophele spoke about AI, Blockchain & Cryptoassets – How disruptive technologies are shaping the future of regulation at user_placeholder and Conference. Read here ➡️url_placeholder url_placeholder',
#        "You're Halloween costume is Sexy + whatever you last searched on Google I'm Sexy Shrug Emoji",
#        'What a great message from user_placeholder to all of our students from user_placeholder Technical Campus Northeast as we kick off Manufacturing Day! user_placeholder user_placeholder user_placeholder url_placeholder',
#        "Authoritarian To-Do List: 1. Build ubiquitous surveillance camera coverage 2. Implement facial recognition to analyze it 3. Ban people from wearing masks at protests It's not just Hong Kong. You could be next. Join the fight to url_placeholder",
#        'user_placeholder If he’s impeached by the House, then “saved” from conviction by the Senate as is suggested here, will he still be able to be prosecuted once out of office? Will he still be able to run in 2020? And use foreign help? url_placeholder',
#        "Friday fun fact: If everyone on Earth took one round trip short-haul flight per year, aircraft emissions would exceed Japan's. One long-haul flight per year, and aviation would be second only to China as a source of CO2. url_placeholder url_placeholder",
#        "Want to know how to manage user_placeholder QR codes? Here's an idea attach it to the child's name tag with a single binder ring. It's simple and easy! user_placeholder user_placeholder user_placeholder url_placeholder",
#        'Watch Bernie lose his sh*t over our bloated Military budget  “No I won’t yield” Gd straight we won’t yield!  This is what leadership looks like folks!    url_placeholder',
#        'url_placeholder',
#        'Delighted to welcome user_placeholder to user_placeholder user_placeholder to find out more about the Linking Leeds social prescribing service led by user_placeholder on behalf of our fantastic partners user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder + many more url_placeholder',
#        'RT user_placeholder Vaping-associated Pulmonary Illnes (VAPI) by user_placeholder url_placeholder',
#        "Netflix's 'Unnatural Selection' brings the existential promise and peril of Crispr gene editing into people’s homes. url_placeholder",
#        'Final session of the day about Food Poverty. Let’s not mince our words says user_placeholder It’s about Poverty, it’s about not having enough money, which has got worse in the UK since the last Labour govt',
#        'user_placeholder I wonder if dull-witted Trump zealots want us to believe that it was nothing more than a coincidence that, according to the Mueller Report, the GRU began helping user_placeholder get elected less than a week after that furtive June 9, 2016 Trump Tower meeting with Veselnitskaya. url_placeholder',
#        'Another pill has been approved by the FDA as an effective tool for  Like Truvada (Descovy offers similar protection in a daily pill which may have less longterm side effects. LINK: url_placeholder url_placeholder',
#        'Thinking of things to do this weekend? 🤔 Why not explore on our City Sightseeing Tour bus?😎 You can hop on and off as much as you like with a 24 hour ticket! More info: url_placeholder url_placeholder',
#        'Heavy rains are expected in over the next 12 hours. teams are on standby. For complaints call 080-22221188, 22100031 & 22975595. Wishing everyone a safe commute home tonight. url_placeholder',
#        'Just and fyi to all my fellow drivers, not stopping for a school bus is a $435 fine, court and license suspension so make sure you stop for your school busses 🙃',
#        'Our new video streaming and DIY electronic music studio. Stay tuned.🎶 user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder user_placeholder url_placeholder',
#        'Never get ill back home yet at uni cant seem to last more than a day without catching the latest strain of the black plague ffs',
#        'caption this url_placeholder',
#        'Well, that’s that on that. No wonder Pompeo tried to block release of these records. It documents it all right here.',
#        'Can someone check the laws in the state of Minnesota to see if there is anything on the books that says the state is required to form its own conference if it has six Div. I hockey programs? K, Thx.',
#        'Collegium recommends names of advocate Sanjeeb Kumar Panigrahi and judicial officer Bibhu Prasad Routray as Judges of url_placeholder',
#        'BHANG grown alongside Maize crop at a farm in Morop location-Rongai was today following an Operation by Detectives led by the Nakuru County Dep. Commissioner. One Suspect; 43-Year-Old Nipson NAMORU, farm caretaker, arrested and assisting in further Investigations. url_placeholder',
#        "What we're seeing in user_placeholder is the same guy he's always been, but (for the first time in his life) with a brand that's hard to destroy: the United States. 1/",
#        'Resting up at home after getting my third cochlear implant... I seem to be making a habit of this! The NHS is a wonderful thing. Looking forward to getting back to full hearing soon...',
#        "There's no special magic here, just the air being pushed out of the way by the truck and the slipstream behind it manipulating the cloud of smoke. Credit - vaping_everywhere on Instagram url_placeholder",
#        'EU VOU NO SHOW DA BILLIE AAAAAAAAAAAAAAAAAAAAAA AAAAAAAAAAAAAAAAAAAAAAAAAA',
#        'Pretty cool to be intro’d at user_placeholder Summit on Economic Mobility as “maybe the most data-driven mayor ever”! Tulsa is using data to bring conversations out of partisan philosophy and into practical problem solving. Thankful this work is inspiring others to do the same. url_placeholder',
#        'Panel discussion: The Reality of 24/7 Surveillance for Incarcerated Readers url_placeholder',
#        'So I’m at user_placeholder looking around the bakery and they have a baker standing next to a full open rack of donuts while icing a cake COUGHING over & over again all over everything. She wasn’t even covering her mouth. Omg🤢🤢',
#        'user_placeholder relies heavily on donations to fund their prison book clubs. Check out more here: url_placeholder',
#        'Gender equality is within our reach - url_placeholder via user_placeholder',
#        'are we all gonna die soon cuz why do i feel like somethin crazy is about to happen',
#        'user_placeholder This is Zuul. She is not wearing a hat but she likes to try on my hair after I blow it dry. url_placeholder',
#        'i had a 12 hour day today, i had 6 hour labs and a lecture, i just deeped that it’s going to be like this for a whole year, how am i going to survive, i wanna d word url_placeholder',
#        'Dropping some visuals from the latest pod episode on youtube tomorrow and over the weekend, stay tuned ⚡️⚡️ url_placeholder',
#        'It’s no small thing that a US Senator and member of Trump’s own party admits he doesn’t take the what the President of the United States says seriously, and suggests the American press does so foolishly. Just chew on that.  url_placeholder',
#        'I can’t wait to have my bachelor’s degree and never have to think again',
#        'FA LA LA LA … here’s the schedule! Watch all November long on user_placeholder See full schedule here: url_placeholder _________ Stay tuned. We’ll be releasing the December schedule soon! url_placeholder',
#        'me: wow i actually have some savings :) a decent start for my post-grad life :) g*ucher about to take all of it and then some so I can study abroad for 3 weeks in a program that has nothing to do with the degree I can’t get without going on said program: 👀',
#        'Un análisis de las barandillas, las máquinas de venta de billetes y las paredes de las estaciones del transporte público permiten crear un "atlas" de comunidades urbanas de microorganismos url_placeholder',
#        'user_placeholder 🔵 url_placeholder',
#        "Thread updating you about China vs The US. You're about to become incredibly smart, wise, you’ll really really like yourself and you’ll wake up tomorrow with new kitchen skills. Year-to-date, the U.S. goods deficit with China is at $199b, down 10.2% from the same time last year url_placeholder",
#        "VIDEO: Saguaros are being bulldozed for the in Organ Pipe Cactus National Monument. Trump's reckless border hysteria is destroying our environment and killing the very species this national monument was designated to protect. Footage by Kevin Dahl, user_placeholder url_placeholder",
#        'Its time to leave the World behind and escape to a Destination Fantasy where deliciously forbidden fruit becomes a reality. Come,  be Captivated, have your hunger Satiated, with a taste of the Creme de la Creme of a Goddess, in the Garden of Ava ! url_placeholder',
#        '43. Oh purée de pomme de terre url_placeholder',
#        'Understanding Risk Factors: Nearly half of all cancer deaths in the United States are the result of potentially preventable causes.',
#        'Kids In The House - Importance of talking to children after you lose it with them. – Life can be stressful and emotions can get the best of us. The question is how do you fix it after you lost it with you child... url_placeholder url_placeholder',
#        'there were 1,551 drug overdose deaths in SRO hotels in San Francisco between 2010-2017 user_placeholder user_placeholder user_placeholder user_placeholder  abstract - National Institute of Health url_placeholder url_placeholder',
#        'This years motto is Health, Wealth and Stealth.',
#        'Uploading this again, but this time tagging user_placeholder You made my year i a video my friend! 🌀♥️⭐️ see you at the 6:15 panel! url_placeholder',
#        "Homer. Herodotus. Sophocles. Plato. Aristotle. Demosthenes. Cicero. Vergil. Male. Male. Male. Male. Male. Male. Male. Male. These authors' names are chiseled into the facade of Columbia University's Butler Library. But now, there's a new banner there. url_placeholder",
#        'Imagine if humans had emergency stop button.🤔',
#        'i have a simple question for new yorkers. who is keeping rice to riches in business?',
#        'Joe Biden tells reporters in Los Angeles re: Trump: "This is a guy that\'s unhinged. He is unhinged. I worry about what he\'s going to do. Not about me or my family. I\'m worried about what he\'ll do in the next year in his presidency."',
#        'After a rough 12 weeks, FAMILY WEEKEND !!! ❤️ url_placeholder'],
#       dtype=object)

# %%
df.head(100).cleaned_text.values[98]
# Out:
# 'China confirms new as it investigates mystery illness  URL'

# %%
df = pd.read_parquet('/mlo-container-scratch/hartley/tweets/parsed_2020-01-09.parquet')
df.head(95).text[93]
# Out:
# '@sachinparadkar @Dr_MR_Satapathy @ArunDeshpande20 @NaniBellary @GauravModified @rajagopalan8 @desertfox61I @anandpdwivedi @UjjwalaDesai @Satishrathod100 @nsitharaman @mygovindia @PMOIndia @narendramodi @nstomar @MoRD_GOI @nsitharamanoffc @ianuragthakur @sukanyaiyer2 @SoniaGurnani19 @chitranayal09 @NPIswaran @ModiBrigade_Ind @Hamara_Desh @DrAVSriv @savitha_rao @VinodKeshava @CantstopulovinM @mahendra3 @shitul905 @lakshmianand96 @LAKSHMISREEKUM3 @Swamy39 @APanagariya @NITIAayog @OnlineRajan__ @utsavpansari @imprernakumari @KSMANN @GSukhpreet @mnreindia @RidhimaTripath4 @FinMinIndia @moefcc @AgriGoI @MoJSDoWRRDGR @Moumita72930219 @athavale_abhi @TheVandeBharat @SwethaAjeeth #Budget2020 FMJi, NRI & Residents be allowed to open Foreign (Major) currency accs Savings, Current Ac in our Banks to enable Instant Free Fund transfers with Inv option in the same currency bringing large inv by🇮🇳s saving Bank fees & ⬆️PSB FC dealings HSBC has global FT opn https://t.co/FqRGHXl3dz'

# %%
cur_hashtags = [find_hash(x).split(',') for x in df.text.values]
df['hashtags'] = cur_hashtags
#df
#np.array([h.split(',') for h in cur_hashtags])

# %%
df
# Out:
#                      id country_code  \
# 0   1178825056782344192           US
# 1   1178827335069523969           US
# 2   1178832448312025089           US
# 3   1178836184660938753         None
# 4   1178836409643393024           US
# ..                  ...          ...
# 89  1179171592892538880           US
# 90  1179173513900392449         None
# 91  1179174538073886720           US
# 92  1179178741358047239           GB
# 93  1179180952167145472         None
#
#                                                  text lang  \
# 0   Dominic & Rey backstage preparing to get destr...   en
# 1   James Harden promised he’d be debuting a new m...   en
# 2   Look let's be honest, @realDonaldTrump's Twitt...   en
# 3   We have a packed #CGSeoul conference! 😍 So man...   en
# 4   Buddy I hate to tell you but there’s no way th...   en
# ..                                                ...  ...
# 89  When your side pieces interact with each other...   en
# 90  idk about y’all but @AdventureDub KILLEDT IT W...   en
# 91  Great seeing my old friend and one of the best...   en
# 92  French comedian  #MarieSinfiltre was was mad f...   en
# 93  Farmer, fisherfolk, and IP leaders from Casigu...   en
#
#                                              hashtags
# 0                                                  []
# 1                                                  []
# 2                                                  []
# 3             [#cgseoul, #bitcoinsv, #bitcoingenesis]
# 4                                                  []
# ..                                                ...
# 89                                                 []
# 90                                                 []
# 91                                                 []
# 92  [#mariesinfiltre, #chanel, #model, #walkthiswa...
# 93                                                 []
#
# [94 rows x 5 columns]

# %%
topics_path = "/mlo-container-scratch/hartley/twitter_covid_insights/insights_All/topics.pkl"
tweets_piped_path  ="/mlo-container-scratch/hartley/tweets_piped"
sub_topics, higher_topics = pkl.load(open(topics_path, 'rb'))

# %%
"""
def update_occs(occs, values) :
    c = Counter()
    c.update([h for x in values for h in x.split(',')])

    for item in c.items() :
        hashtag, count = item
        to_prepend = day_nb - len(occs[hashtag])
        occs[hashtag] += [0]*to_prepend + [count]

files = [os.path.join(tweets_piped_path,f) for f in  sorted(os.listdir(tweets_piped_path))]
occs     = defaultdict(lambda : [])
pos_occs = defaultdict(lambda : [])
    
# Build occurences per day
for day_nb, f in tqdm(enumerate(files), total=len(files), desc='occs') :
    df = pd.read_parquet(f, columns=['hashtags', 'sentiment'])
    update_occs(occs, df.hashtags)
    update_occs(pos_occs, df[df.sentiment == 1].hashtags)

# Append missing zeros at the end
nb_days = len(files)
for k in occs :
    occs[k] += [0]*(nb_days-len(occs[k]))
    occs[k] = np.array(occs[k])

    if k in pos_occs : 
        pos_occs[k] += [0]*(nb_days-len(pos_occs[k]))
        pos_occs[k] = np.array(pos_occs[k])


# Derive neg_occs
neg_occs = {tag : occs[tag] - pos_occs[tag] if tag in pos_occs else occs[tag] for tag in occs}

"""
# Compute trends
print(f"There are {len(sub_topics)} topics and {len(higher_topics)} higher topics")
sub_trends, higher_trends = {}, {}

# Build trends for sub-topics TODO check correct axis
for idx, hashtags in tqdm(sub_topics.items(), desc='sub_topics') :
    #print(f'sub_topic with hashtags {hashtags}')
    for h in hashtags :
        sub_trends[str(idx)]       = np.sum([occs[h]     for h in hashtags if len(occs[h])], axis=0)
        sub_trends['Pos-'+str(idx)] = np.sum([pos_occs[h] for h in hashtags if len(pos_occs[h])], axis=0)
        sub_trends['Neg-'+str(idx)] = np.sum([neg_occs[h] for h in hashtags if len(neg_occs[h])], axis=0)


for idx, subs in higher_topics.items() :
    subs = [str(x) for x in subs]
    higher_trends[str(idx)]       = np.sum([sub_trends[x]       for x in subs], axis=0)
    higher_trends['Pos-'+str(idx)] = np.sum([sub_trends['Pos-'+x] for x in subs], axis=0)
    higher_trends['Neg-'+str(idx)] = np.sum([sub_trends['Pos-'+x] for x in subs], axis=0)
# Out:
# sub_topics:   1%|▏         | 12/858 [00:00<00:07, 112.43it/s]
# There are 858 topics and 10 higher topics
# sub_topics: 100%|██████████| 858/858 [00:03<00:00, 250.72it/s]

# %%
len(occs)
# Out:
# 4154947

# %%
ls /mlo-container-scratch/hartley/tweets_piped
# Out:
# parsed_2019-10-01.parquet  parsed_2020-02-22.parquet  parsed_2020-07-15.parquet
# parsed_2019-10-02.parquet  parsed_2020-02-23.parquet  parsed_2020-07-16.parquet
# parsed_2019-10-03.parquet  parsed_2020-02-24.parquet  parsed_2020-07-17.parquet
# parsed_2019-10-04.parquet  parsed_2020-02-25.parquet  parsed_2020-07-18.parquet
# parsed_2019-10-05.parquet  parsed_2020-02-26.parquet  parsed_2020-07-19.parquet
# parsed_2019-10-06.parquet  parsed_2020-02-27.parquet  parsed_2020-07-20.parquet
# parsed_2019-10-07.parquet  parsed_2020-02-28.parquet  parsed_2020-07-21.parquet
# parsed_2019-10-08.parquet  parsed_2020-02-29.parquet  parsed_2020-07-22.parquet
# parsed_2019-10-09.parquet  parsed_2020-03-01.parquet  parsed_2020-07-23.parquet
# parsed_2019-10-10.parquet  parsed_2020-03-02.parquet  parsed_2020-07-24.parquet
# parsed_2019-10-11.parquet  parsed_2020-03-03.parquet  parsed_2020-07-25.parquet
# parsed_2019-10-12.parquet  parsed_2020-03-04.parquet  parsed_2020-07-26.parquet
# parsed_2019-10-13.parquet  parsed_2020-03-05.parquet  parsed_2020-07-27.parquet
# parsed_2019-10-14.parquet  parsed_2020-03-06.parquet  parsed_2020-07-28.parquet
# parsed_2019-10-15.parquet  parsed_2020-03-07.parquet  parsed_2020-07-29.parquet
# parsed_2019-10-16.parquet  parsed_2020-03-08.parquet  parsed_2020-07-30.parquet
# parsed_2019-10-17.parquet  parsed_2020-03-09.parquet  parsed_2020-07-31.parquet
# parsed_2019-10-18.parquet  parsed_2020-03-10.parquet  parsed_2020-08-01.parquet
# parsed_2019-10-19.parquet  parsed_2020-03-11.parquet  parsed_2020-08-02.parquet
# parsed_2019-10-20.parquet  parsed_2020-03-12.parquet  parsed_2020-08-03.parquet
# parsed_2019-10-21.parquet  parsed_2020-03-13.parquet  parsed_2020-08-04.parquet
# parsed_2019-10-22.parquet  parsed_2020-03-14.parquet  parsed_2020-08-05.parquet
# parsed_2019-10-23.parquet  parsed_2020-03-15.parquet  parsed_2020-08-06.parquet
# parsed_2019-10-24.parquet  parsed_2020-03-16.parquet  parsed_2020-08-07.parquet
# parsed_2019-10-25.parquet  parsed_2020-03-17.parquet  parsed_2020-08-08.parquet
# parsed_2019-10-26.parquet  parsed_2020-03-18.parquet  parsed_2020-08-09.parquet
# parsed_2019-10-27.parquet  parsed_2020-03-19.parquet  parsed_2020-08-10.parquet
# parsed_2019-10-28.parquet  parsed_2020-03-20.parquet  parsed_2020-08-11.parquet
# parsed_2019-10-29.parquet  parsed_2020-03-21.parquet  parsed_2020-08-12.parquet
# parsed_2019-10-30.parquet  parsed_2020-03-22.parquet  parsed_2020-08-13.parquet
# parsed_2019-10-31.parquet  parsed_2020-03-23.parquet  parsed_2020-08-14.parquet
# parsed_2019-11-01.parquet  parsed_2020-03-24.parquet  parsed_2020-08-15.parquet
# parsed_2019-11-02.parquet  parsed_2020-03-25.parquet  parsed_2020-08-16.parquet
# parsed_2019-11-03.parquet  parsed_2020-03-26.parquet  parsed_2020-08-17.parquet
# parsed_2019-11-04.parquet  parsed_2020-03-27.parquet  parsed_2020-08-18.parquet
# parsed_2019-11-05.parquet  parsed_2020-03-28.parquet  parsed_2020-08-19.parquet
# parsed_2019-11-06.parquet  parsed_2020-03-29.parquet  parsed_2020-08-20.parquet
# parsed_2019-11-07.parquet  parsed_2020-03-30.parquet  parsed_2020-08-21.parquet
# parsed_2019-11-08.parquet  parsed_2020-03-31.parquet  parsed_2020-08-22.parquet
# parsed_2019-11-09.parquet  parsed_2020-04-01.parquet  parsed_2020-08-23.parquet
# parsed_2019-11-10.parquet  parsed_2020-04-02.parquet  parsed_2020-08-24.parquet
# parsed_2019-11-11.parquet  parsed_2020-04-03.parquet  parsed_2020-08-25.parquet
# parsed_2019-11-12.parquet  parsed_2020-04-04.parquet  parsed_2020-08-26.parquet
# parsed_2019-11-13.parquet  parsed_2020-04-05.parquet  parsed_2020-08-27.parquet
# parsed_2019-11-14.parquet  parsed_2020-04-06.parquet  parsed_2020-08-28.parquet
# parsed_2019-11-15.parquet  parsed_2020-04-07.parquet  parsed_2020-08-29.parquet
# parsed_2019-11-16.parquet  parsed_2020-04-08.parquet  parsed_2020-08-30.parquet
# parsed_2019-11-17.parquet  parsed_2020-04-09.parquet  parsed_2020-08-31.parquet
# parsed_2019-11-18.parquet  parsed_2020-04-10.parquet  parsed_2020-09-01.parquet
# parsed_2019-11-19.parquet  parsed_2020-04-11.parquet  parsed_2020-09-02.parquet
# parsed_2019-11-20.parquet  parsed_2020-04-12.parquet  parsed_2020-09-03.parquet
# parsed_2019-11-21.parquet  parsed_2020-04-13.parquet  parsed_2020-09-04.parquet
# parsed_2019-11-22.parquet  parsed_2020-04-14.parquet  parsed_2020-09-05.parquet
# parsed_2019-11-23.parquet  parsed_2020-04-15.parquet  parsed_2020-09-06.parquet
# parsed_2019-11-24.parquet  parsed_2020-04-16.parquet  parsed_2020-09-07.parquet
# parsed_2019-11-25.parquet  parsed_2020-04-17.parquet  parsed_2020-09-08.parquet
# parsed_2019-11-26.parquet  parsed_2020-04-18.parquet  parsed_2020-09-09.parquet
# parsed_2019-11-27.parquet  parsed_2020-04-19.parquet  parsed_2020-09-10.parquet
# parsed_2019-11-28.parquet  parsed_2020-04-20.parquet  parsed_2020-09-11.parquet
# parsed_2019-11-29.parquet  parsed_2020-04-21.parquet  parsed_2020-09-12.parquet
# parsed_2019-11-30.parquet  parsed_2020-04-22.parquet  parsed_2020-09-13.parquet
# parsed_2019-12-01.parquet  parsed_2020-04-23.parquet  parsed_2020-09-14.parquet
# parsed_2019-12-02.parquet  parsed_2020-04-24.parquet  parsed_2020-09-15.parquet
# parsed_2019-12-03.parquet  parsed_2020-04-25.parquet  parsed_2020-09-16.parquet
# parsed_2019-12-04.parquet  parsed_2020-04-26.parquet  parsed_2020-09-17.parquet
# parsed_2019-12-05.parquet  parsed_2020-04-27.parquet  parsed_2020-09-18.parquet
# parsed_2019-12-06.parquet  parsed_2020-04-28.parquet  parsed_2020-09-19.parquet
# parsed_2019-12-07.parquet  parsed_2020-04-29.parquet  parsed_2020-09-20.parquet
# parsed_2019-12-08.parquet  parsed_2020-04-30.parquet  parsed_2020-09-21.parquet
# parsed_2019-12-09.parquet  parsed_2020-05-01.parquet  parsed_2020-09-22.parquet
# parsed_2019-12-10.parquet  parsed_2020-05-02.parquet  parsed_2020-09-23.parquet
# parsed_2019-12-11.parquet  parsed_2020-05-03.parquet  parsed_2020-09-24.parquet
# parsed_2019-12-12.parquet  parsed_2020-05-04.parquet  parsed_2020-09-25.parquet
# parsed_2019-12-13.parquet  parsed_2020-05-05.parquet  parsed_2020-09-26.parquet
# parsed_2019-12-14.parquet  parsed_2020-05-06.parquet  parsed_2020-09-27.parquet
# parsed_2019-12-15.parquet  parsed_2020-05-07.parquet  parsed_2020-09-28.parquet
# parsed_2019-12-16.parquet  parsed_2020-05-08.parquet  parsed_2020-09-29.parquet
# parsed_2019-12-17.parquet  parsed_2020-05-09.parquet  parsed_2020-09-30.parquet
# parsed_2019-12-18.parquet  parsed_2020-05-10.parquet  parsed_2020-10-01.parquet
# parsed_2019-12-19.parquet  parsed_2020-05-11.parquet  parsed_2020-10-02.parquet
# parsed_2019-12-20.parquet  parsed_2020-05-12.parquet  parsed_2020-10-03.parquet
# parsed_2019-12-21.parquet  parsed_2020-05-13.parquet  parsed_2020-10-04.parquet
# parsed_2019-12-22.parquet  parsed_2020-05-14.parquet  parsed_2020-10-05.parquet
# parsed_2019-12-23.parquet  parsed_2020-05-15.parquet  parsed_2020-10-06.parquet
# parsed_2019-12-24.parquet  parsed_2020-05-16.parquet  parsed_2020-10-07.parquet
# parsed_2019-12-25.parquet  parsed_2020-05-17.parquet  parsed_2020-10-08.parquet
# parsed_2019-12-26.parquet  parsed_2020-05-18.parquet  parsed_2020-10-09.parquet
# parsed_2019-12-27.parquet  parsed_2020-05-19.parquet  parsed_2020-10-10.parquet
# parsed_2019-12-28.parquet  parsed_2020-05-20.parquet  parsed_2020-10-11.parquet
# parsed_2019-12-29.parquet  parsed_2020-05-21.parquet  parsed_2020-10-12.parquet
# parsed_2019-12-30.parquet  parsed_2020-05-22.parquet  parsed_2020-10-13.parquet
# parsed_2019-12-31.parquet  parsed_2020-05-23.parquet  parsed_2020-10-14.parquet
# parsed_2020-01-01.parquet  parsed_2020-05-24.parquet  parsed_2020-10-15.parquet
# parsed_2020-01-02.parquet  parsed_2020-05-25.parquet  parsed_2020-10-16.parquet
# parsed_2020-01-03.parquet  parsed_2020-05-26.parquet  parsed_2020-10-17.parquet
# parsed_2020-01-04.parquet  parsed_2020-05-27.parquet  parsed_2020-10-18.parquet
# parsed_2020-01-05.parquet  parsed_2020-05-28.parquet  parsed_2020-10-19.parquet
# parsed_2020-01-06.parquet  parsed_2020-05-29.parquet  parsed_2020-10-20.parquet
# parsed_2020-01-07.parquet  parsed_2020-05-30.parquet  parsed_2020-10-21.parquet
# parsed_2020-01-08.parquet  parsed_2020-05-31.parquet  parsed_2020-10-22.parquet
# parsed_2020-01-09.parquet  parsed_2020-06-01.parquet  parsed_2020-10-23.parquet
# parsed_2020-01-10.parquet  parsed_2020-06-02.parquet  parsed_2020-10-24.parquet
# parsed_2020-01-11.parquet  parsed_2020-06-03.parquet  parsed_2020-10-25.parquet
# parsed_2020-01-12.parquet  parsed_2020-06-04.parquet  parsed_2020-10-26.parquet
# parsed_2020-01-13.parquet  parsed_2020-06-05.parquet  parsed_2020-10-27.parquet
# parsed_2020-01-14.parquet  parsed_2020-06-06.parquet  parsed_2020-10-28.parquet
# parsed_2020-01-15.parquet  parsed_2020-06-07.parquet  parsed_2020-10-29.parquet
# parsed_2020-01-16.parquet  parsed_2020-06-08.parquet  parsed_2020-10-30.parquet
# parsed_2020-01-17.parquet  parsed_2020-06-09.parquet  parsed_2020-10-31.parquet
# parsed_2020-01-18.parquet  parsed_2020-06-10.parquet  parsed_2020-11-01.parquet
# parsed_2020-01-19.parquet  parsed_2020-06-11.parquet  parsed_2020-11-02.parquet
# parsed_2020-01-20.parquet  parsed_2020-06-12.parquet  parsed_2020-11-03.parquet
# parsed_2020-01-21.parquet  parsed_2020-06-13.parquet  parsed_2020-11-04.parquet
# parsed_2020-01-22.parquet  parsed_2020-06-14.parquet  parsed_2020-11-05.parquet
# parsed_2020-01-23.parquet  parsed_2020-06-15.parquet  parsed_2020-11-06.parquet
# parsed_2020-01-24.parquet  parsed_2020-06-16.parquet  parsed_2020-11-07.parquet
# parsed_2020-01-25.parquet  parsed_2020-06-17.parquet  parsed_2020-11-08.parquet
# parsed_2020-01-26.parquet  parsed_2020-06-18.parquet  parsed_2020-11-09.parquet
# parsed_2020-01-27.parquet  parsed_2020-06-19.parquet  parsed_2020-11-10.parquet
# parsed_2020-01-28.parquet  parsed_2020-06-20.parquet  parsed_2020-11-11.parquet
# parsed_2020-01-29.parquet  parsed_2020-06-21.parquet  parsed_2020-11-12.parquet
# parsed_2020-01-30.parquet  parsed_2020-06-22.parquet  parsed_2020-11-13.parquet
# parsed_2020-01-31.parquet  parsed_2020-06-23.parquet  parsed_2020-11-14.parquet
# parsed_2020-02-01.parquet  parsed_2020-06-24.parquet  parsed_2020-11-15.parquet
# parsed_2020-02-02.parquet  parsed_2020-06-25.parquet  parsed_2020-11-16.parquet
# parsed_2020-02-03.parquet  parsed_2020-06-26.parquet  parsed_2020-11-17.parquet
# parsed_2020-02-04.parquet  parsed_2020-06-27.parquet  parsed_2020-11-18.parquet
# parsed_2020-02-05.parquet  parsed_2020-06-28.parquet  parsed_2020-11-19.parquet
# parsed_2020-02-06.parquet  parsed_2020-06-29.parquet  parsed_2020-11-20.parquet
# parsed_2020-02-07.parquet  parsed_2020-06-30.parquet  parsed_2020-11-21.parquet
# parsed_2020-02-08.parquet  parsed_2020-07-01.parquet  parsed_2020-11-22.parquet
# parsed_2020-02-09.parquet  parsed_2020-07-02.parquet  parsed_2020-11-23.parquet
# parsed_2020-02-10.parquet  parsed_2020-07-03.parquet  parsed_2020-11-24.parquet
# parsed_2020-02-11.parquet  parsed_2020-07-04.parquet  parsed_2020-11-25.parquet
# parsed_2020-02-12.parquet  parsed_2020-07-05.parquet  parsed_2020-11-26.parquet
# parsed_2020-02-13.parquet  parsed_2020-07-06.parquet  parsed_2020-11-27.parquet
# parsed_2020-02-14.parquet  parsed_2020-07-07.parquet  parsed_2020-11-28.parquet
# parsed_2020-02-15.parquet  parsed_2020-07-08.parquet  parsed_2020-11-29.parquet
# parsed_2020-02-16.parquet  parsed_2020-07-09.parquet  parsed_2020-11-30.parquet
# parsed_2020-02-17.parquet  parsed_2020-07-10.parquet  parsed_2020-12-01.parquet
# parsed_2020-02-18.parquet  parsed_2020-07-11.parquet  parsed_2020-12-02.parquet
# parsed_2020-02-19.parquet  parsed_2020-07-12.parquet  parsed_2020-12-03.parquet
# parsed_2020-02-20.parquet  parsed_2020-07-13.parquet
# parsed_2020-02-21.parquet  parsed_2020-07-14.parquet
